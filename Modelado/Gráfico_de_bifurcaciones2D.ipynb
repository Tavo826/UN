# %% [markdown]
# <a href="https://colab.research.google.com/github/Tavo826/UN/blob/main/Gr%C3%A1fico_de_bifurcaciones2D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

# %% [markdown]
# # Función $\dot{x} = r + x^2$

# %%
# Análisis de la función



x = np.linspace(-2,2,100)

def func(x, r):
  x_dot = r + x**2
  return x_dot

# r < 0
r1 = -2
x1 = func(x, r1)
plt.plot(x,x1, label='r < 0')

# r = 0
r2 = 0
x2 = func(x, r2)
plt.plot(x,x2, label='r = 0')

# r > 0
r3 = 2
x3 = func(x, r3)
plt.plot(x,x3, label='r > 0')

plt.grid()
plt.legend(loc='best')
plt.show()
